# %% [markdown]
# # Image Manipulation with skimage

# %% [markdown]
# This example builds a simple UI for performing basic image manipulation with [scikit-image](http://scikit-image.org/).

# %%
from ipywidgets import interact, interactive, fixed
from IPython.display import display

# %%
import skimage
from skimage import data, filters, io

# %%
i = data.coffee()

# %%
io.Image(i)
# Out:
# Image([[[ 21,  13,   8],
#         [ 21,  13,   9],
#         [ 20,  11,   8],
#         ...,
#         [228, 182, 138],
#         [231, 185, 142],
#         [228, 184, 140]],
#
#        [[ 21,  13,   7],
#         [ 21,  13,   9],
#         [ 20,  14,   7],
#         ...,
#         [228, 182, 136],
#         [231, 185, 139],
#         [229, 183, 137]],
#
#        [[ 21,  14,   7],
#         [ 23,  13,  10],
#         [ 20,  14,   9],
#         ...,
#         [228, 182, 136],
#         [228, 184, 137],
#         [229, 185, 138]],
#
#        ...,
#        [[189, 124,  77],
#         [214, 155, 109],
#         [197, 141, 100],
#         ...,
#         [165,  86,  37],
#         [161,  82,  41],
#         [143,  67,  29]],
#
#        [[207, 148, 102],
#         [201, 142,  99],
#         [196, 140,  97],
#         ...,
#         [154,  74,  37],
#         [147,  66,  33],
#         [145,  65,  31]],
#
#        [[197, 141, 100],
#         [195, 137,  99],
#         [193, 138,  98],
#         ...,
#         [158,  73,  38],
#         [144,  64,  30],
#         [143,  60,  29]]], dtype=uint8)

# %%
def edit_image(image, sigma=0.1, r=1.0, g=1.0, b=1.0):
    new_image = filters.gaussian_filter(image, sigma=sigma, multichannel=True)
    new_image[:,:,0] = r*new_image[:,:,0]
    new_image[:,:,1] = g*new_image[:,:,1]
    new_image[:,:,2] = b*new_image[:,:,2]
    new_image = io.Image(new_image)
    return new_image

# %%
lims = (0.0,1.0,0.01)
w = interactive(edit_image, image=fixed(i), sigma=(0.0,10.0,0.1), r=lims, g=lims, b=lims)
display(w)
# Out:
# Image([[[ 0.08218031,  0.04414078,  0.02663159],
#         [ 0.08240771,  0.0444234 ,  0.02704719],
#         [ 0.08276467,  0.04483316,  0.02744578],
#         ...,
#         [ 0.88528147,  0.60711303,  0.46454671],
#         [ 0.88829356,  0.61051973,  0.46749069],
#         [ 0.8905504 ,  0.61328192,  0.46985903]],
#
#        [[ 0.08202952,  0.04409594,  0.02609118],
#         [ 0.08228752,  0.04439435,  0.02656107],
#         [ 0.08267724,  0.04481841,  0.02702792],
#         ...,
#         [ 0.88364532,  0.60563312,  0.46281862],
#         [ 0.8866858 ,  0.60893422,  0.46562059],
#         [ 0.88901596,  0.61165712,  0.46794191]],
#
#        [[ 0.08178028,  0.04396597,  0.02554479],
#         [ 0.08207597,  0.04427983,  0.02605507],
#         [ 0.0825065 ,  0.044718  ,  0.02657693],
#         ...,
#         [ 0.88147973,  0.6036485 ,  0.46075142],
#         [ 0.88445186,  0.60670475,  0.4632446 ],
#         [ 0.88678057,  0.60927464,  0.46537718]],
#
#        ...,
#        [[ 0.75572135,  0.45589904,  0.31784144],
#         [ 0.75980628,  0.46018354,  0.32189998],
#         [ 0.76443076,  0.46527128,  0.32656559],
#         ...,
#         [ 0.58757699,  0.23358716,  0.11050554],
#         [ 0.58900786,  0.23385372,  0.1107267 ],
#         [ 0.58931687,  0.23352964,  0.11069288]],
#
#        [[ 0.75974127,  0.4596787 ,  0.32220779],
#         [ 0.76361917,  0.46380704,  0.32615547],
#         [ 0.76811284,  0.46879983,  0.33077046],
#         ...,
#         [ 0.58778263,  0.23278047,  0.1104714 ],
#         [ 0.58805531,  0.23200093,  0.11013389],
#         [ 0.58710615,  0.23064677,  0.10958099]],
#
#        [[ 0.7639473 ,  0.46384456,  0.32699251],
#         [ 0.7675414 ,  0.46769176,  0.33069565],
#         [ 0.77184485,  0.4724772 ,  0.33513639],
#         ...,
#         [ 0.58771334,  0.23164213,  0.11025039],
#         [ 0.58693448,  0.22993197,  0.10943806],
#         [ 0.58489955,  0.22768992,  0.10845918]]])

# %%
w.result
# Out:
# /home/jon/.local/lib/python3.4/site-packages/skimage/util/dtype.py:111: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# Image([[[ 0.08218031,  0.04414078,  0.02663159],
#         [ 0.08240771,  0.0444234 ,  0.02704719],
#         [ 0.08276467,  0.04483316,  0.02744578],
#         ...,
#         [ 0.88528147,  0.60711303,  0.46454671],
#         [ 0.88829356,  0.61051973,  0.46749069],
#         [ 0.8905504 ,  0.61328192,  0.46985903]],
#
#        [[ 0.08202952,  0.04409594,  0.02609118],
#         [ 0.08228752,  0.04439435,  0.02656107],
#         [ 0.08267724,  0.04481841,  0.02702792],
#         ...,
#         [ 0.88364532,  0.60563312,  0.46281862],
#         [ 0.8866858 ,  0.60893422,  0.46562059],
#         [ 0.88901596,  0.61165712,  0.46794191]],
#
#        [[ 0.08178028,  0.04396597,  0.02554479],
#         [ 0.08207597,  0.04427983,  0.02605507],
#         [ 0.0825065 ,  0.044718  ,  0.02657693],
#         ...,
#         [ 0.88147973,  0.6036485 ,  0.46075142],
#         [ 0.88445186,  0.60670475,  0.4632446 ],
#         [ 0.88678057,  0.60927464,  0.46537718]],
#
#        ...,
#        [[ 0.75572135,  0.45589904,  0.31784144],
#         [ 0.75980628,  0.46018354,  0.32189998],
#         [ 0.76443076,  0.46527128,  0.32656559],
#         ...,
#         [ 0.58757699,  0.23358716,  0.11050554],
#         [ 0.58900786,  0.23385372,  0.1107267 ],
#         [ 0.58931687,  0.23352964,  0.11069288]],
#
#        [[ 0.75974127,  0.4596787 ,  0.32220779],
#         [ 0.76361917,  0.46380704,  0.32615547],
#         [ 0.76811284,  0.46879983,  0.33077046],
#         ...,
#         [ 0.58778263,  0.23278047,  0.1104714 ],
#         [ 0.58805531,  0.23200093,  0.11013389],
#         [ 0.58710615,  0.23064677,  0.10958099]],
#
#        [[ 0.7639473 ,  0.46384456,  0.32699251],
#         [ 0.7675414 ,  0.46769176,  0.33069565],
#         [ 0.77184485,  0.4724772 ,  0.33513639],
#         ...,
#         [ 0.58771334,  0.23164213,  0.11025039],
#         [ 0.58693448,  0.22993197,  0.10943806],
#         [ 0.58489955,  0.22768992,  0.10845918]]])

# %% [markdown]
# ## Python 3 only: Function annotations

# %% [markdown]
# In Python 3, you can use the new function annotation syntax to describe widgets for interact:

# %%
lims = (0.0,1.0,0.01)

@interact
def edit_image(image: fixed(i), sigma:(0.0,10.0,0.1)=0.1, r:lims=1.0, g:lims=1.0, b:lims=1.0):
    new_image = filters.gaussian_filter(image, sigma=sigma, multichannel=True)
    new_image[:,:,0] = r*new_image[:,:,0]
    new_image[:,:,1] = g*new_image[:,:,1]
    new_image[:,:,2] = b*new_image[:,:,2]
    new_image = io.Image(new_image)
    return new_image
# Out:
# Image([[[ 0.03211765,  0.05098039,  0.03137255],
#         [ 0.03211765,  0.05098039,  0.03529412],
#         [ 0.03058824,  0.04313725,  0.03137255],
#         ...,
#         [ 0.34870588,  0.71372549,  0.54117647],
#         [ 0.35329412,  0.7254902 ,  0.55686275],
#         [ 0.34870588,  0.72156863,  0.54901961]],
#
#        [[ 0.03211765,  0.05098039,  0.02745098],
#         [ 0.03211765,  0.05098039,  0.03529412],
#         [ 0.03058824,  0.05490196,  0.02745098],
#         ...,
#         [ 0.34870588,  0.71372549,  0.53333333],
#         [ 0.35329412,  0.7254902 ,  0.54509804],
#         [ 0.35023529,  0.71764706,  0.5372549 ]],
#
#        [[ 0.03211765,  0.05490196,  0.02745098],
#         [ 0.03517647,  0.05098039,  0.03921569],
#         [ 0.03058824,  0.05490196,  0.03529412],
#         ...,
#         [ 0.34870588,  0.71372549,  0.53333333],
#         [ 0.34870588,  0.72156863,  0.5372549 ],
#         [ 0.35023529,  0.7254902 ,  0.54117647]],
#
#        ...,
#        [[ 0.28905882,  0.48627451,  0.30196078],
#         [ 0.32729412,  0.60784314,  0.42745098],
#         [ 0.30129412,  0.55294118,  0.39215686],
#         ...,
#         [ 0.25235294,  0.3372549 ,  0.14509804],
#         [ 0.24623529,  0.32156863,  0.16078431],
#         [ 0.21870588,  0.2627451 ,  0.11372549]],
#
#        [[ 0.31658824,  0.58039216,  0.4       ],
#         [ 0.30741176,  0.55686275,  0.38823529],
#         [ 0.29976471,  0.54901961,  0.38039216],
#         ...,
#         [ 0.23552941,  0.29019608,  0.14509804],
#         [ 0.22482353,  0.25882353,  0.12941176],
#         [ 0.22176471,  0.25490196,  0.12156863]],
#
#        [[ 0.30129412,  0.55294118,  0.39215686],
#         [ 0.29823529,  0.5372549 ,  0.38823529],
#         [ 0.29517647,  0.54117647,  0.38431373],
#         ...,
#         [ 0.24164706,  0.28627451,  0.14901961],
#         [ 0.22023529,  0.25098039,  0.11764706],
#         [ 0.21870588,  0.23529412,  0.11372549]]])
